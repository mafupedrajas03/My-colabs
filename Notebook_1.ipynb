# %% [markdown]
# # 🐍 Introducción a Python: Tipos y Variables
#
# En este cuaderno vas a practicar los conceptos más básicos de Python:
#
# - Cómo crear variables
# - Cómo imprimirlas en pantalla
# - Cómo trabajar con los tipos de datos primitivos
# - Cómo hacer operaciones simples

# %% [markdown]
# <a align="center">
#     <img src="https://drive.google.com/uc?id=1E5Ql9Ee2xK_1dxgeIuGeov7ikNo3I92b&export=download" width="600">
# </a>

# %% [markdown]
# ## INT – Tipo entero

# %% [markdown]
# <p>Estos son algunos ejemplos de números enteros. Los números enteros pueden ser números negativos o positivos:</p>

# %% [markdown]
# <a align="center">
#     <img src="https://drive.google.com/uc?id=10BI1FW8XZNF60xwEyOlV0fJMYl7DzClc&export=download" width="600">
# </a>

# %% [markdown]
# Asigna un valor de tipo **int** a nuestra variable llamada edad y muestrala por pantalla.

# %%
#Dale al play o apreta SHIFT+ENTER
edad = 22
edad
# Out:
# 22

# %% [markdown]
# Ejercicio:
# 1. Dadas las dos variables enteras 'a' y 'b' asignales dos valores diferentes

# %%
a = 2
b = 3

# Imprime solo la primera variable
a
# Out:
# 2

# %%
#Aquí imprime la segunda
b
# Out:
# 3

# %% [markdown]
# ## FLOAT – Tipo decimal
#
# 1. Dada la variable llamada altura, asigna un valor de tipo **float** a nuestra variable
# 2. Dale al play

# %%
altura = 1.75
altura
# Out:
# 1.75

# %% [markdown]
# Ejercicio
# 1. Asigna el valor decimal de lo último que hayas comprado a la variable 'precio'
# 2. Imprime la variable precio

# %%
precio = 4.99

# Imprime la variable precio

# %%
precio
# Out:
# 4.99

# %% [markdown]
# ## STR – Tipo texto
#
# 1. Dada la siguiente variable, asigna tu nombre como valor de tipo **string** a nuestra variable
# 2. Y muestrala por pantalla.

# %%
nombre = "Mafalda"
nombre
# Out:
# 'Mafalda'

# %% [markdown]
# Ejercicio:
# 1. Crea una variable saludo con el texto "Hola The Valley!"
# 2. Imprime la variable saludo

# %%
# Ejercicio: Crea una variable saludo con el texto "Hola The Valley!"
saludo = "Hola The Valley!"

# Imprime la variable saludo
saludo
# Out:
# 'Hola The Valley!'

# %% [markdown]
# ## BOOL – Tipo booleano
#
# 1. Crea una variable con el nombre que quieras y asigna un valor de tipo **bool** a nuestra variable
# 2. Y dale al play

# %%
es_estudiante = True

es_estudiante
# Out:
# True

# %% [markdown]
# Ejercicio: Dada la variable 'tiene_hambre' asigna un valor False o True dependiendo de si tienes hambre o no

# %%
tiene_hambre = True

# Imprime la variable tiene_hambre
tiene_hambre
# Out:
# True

# %% [markdown]
# Ejercicio
# 1. Crea una variable que se llame como tú quieras y asignale un valor
# 2. Imprime tu variable

# %%
# Ejercicio
# 1. Crea una variable que se llame como tú quieras y asignale un valor
mi_casa = "Grande"

# 2. Imprime tu variable
mi_casa
# Out:
# 'Grande'

# %% [markdown]
# ## Operaciones aritméticas básicas
#
# 1. Asigna dos valores númericos a las variables
# 2. Suma las variables
# 3. Guarda el resultado en otra variable.
# 4. Luego imprímelo.

# %%
#PASO 1
numero1 = 2
numero2 = 3

#PASO 2 y 3
suma = numero1 + numero2

#PASO 4
suma
# Out:
# 5

# %% [markdown]
# Ejercicio: Suma dos números y guarda el resultado en 'resultado_suma'

# %%
# No debes hacer referencia al valor, solo al nombre de la variable
num1 = 10
num2 = 5
resultado_suma = num1 + num2

# Imprime el resultado de la suma
resultado_suma
# Out:
# 15

# %% [markdown]
# Ejercicio:
# 1. Resta dos números y guarda el resultado en 'resultado_resta'

# %%
num3 = 8
num4 = 3
resultado_resta = num3 - num4

# Imprime el resultado
resultado_resta
# Out:
# 5

# %% [markdown]
# Ejercicio:
# 1. Multiplica dos números y guarda el resultado

# %%
num5 = 7
num6 = 6
resultado_multiplicacion = num5 * num6

# Imprime el resultado
resultado_multiplicacion
# Out:
# 42

# %% [markdown]
# Ejercicio:
# 1. Divide dos números y guarda el resultado

# %%
num7 = 20
num8 = 4
resultado_division = num7 / num8

# Imprime el resultado
resultado_division
# Out:
# 5.0

# %% [markdown]
# RETO:
#
# Mientras todos nos adaptamos al nuevo entorno intenta instalar la última versión de Python en local (en tu ordenador). Y acto seguido, el IDE que sea de tu preferencia. Por último, intenta abrir y ejecutar esta Notebook en tu propio entorno.
