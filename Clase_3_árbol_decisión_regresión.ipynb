# %% [markdown]
# # 1.Árboles de decisión para regresión
# Algoritmo de aprendizaje supervisado para regresión que construye un árbol de decisión dividiendo el conjunto de datos en nodos mediante reglas del tipo “si X ≤ umbral” (o por categorías).
#
# En cada partición elige la variable y el umbral que mejor reducen el error al predecir un valor continuo (por ejemplo, minimizando la varianza, el MSE o el MAE) y, en las hojas, devuelve una predicción numérica (normalmente la media  del objetivo en ese nodo).

# %% [markdown]
# # 00. Error Cuadrático Medio y Raiz del Error Cuadrático Medio
#
# **El error medio cuadrático** (MSE, por sus siglas en inglés) es una métrica comúnmente utilizada para evaluar el rendimiento de modelos de regresión.
# El MSE mide la diferencia promedio al cuadrado entre los valores predichos por un modelo y los valores reales observados. Matemáticamente, se define como:
#
# $$
# \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# La fórmula de la **raíz del error cuadrático medio** (RECM) es:
#
# $$
# \text{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2}
# $$

# %% [markdown]
# ## 1.1 Intro: RMSE

# %%
#rmse_ se usa mas para explicar a negocio
#mse se usa mas para optimizacion interna

# %%
from sklearn.metrics import mean_squared_error, root_mean_squared_error

# vector de valores reales
y_true = [3.0, -0.5, 2.0, 7.0]
# vector de predicciones
y_pred = [3.0, -0.5, 2.0, 7.0]

mse = mean_squared_error(y_true, y_pred)
print("Mean Squared Error:", mse)

rmse = root_mean_squared_error(y_true, y_pred)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.0
# Root Mean Squared Error: 0.0

# %%
y_true = [3.0, -0.5, 2.0, 7.0]
y_pred = [2.8, 0.0, 2.1, 7.2]

mse = mean_squared_error(y_true, y_pred)
print("Mean Squared Error:", mse)

rmse = root_mean_squared_error(y_true, y_pred)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.08500000000000005
# Root Mean Squared Error: 0.2915475947422651

# %%
y_true = [3.0, -0.5, 2.0, 7.0]
y_pred = [4.5, 3.6, 3.1, 17.8]

mse = mean_squared_error(y_true, y_pred)
print("Mean Squared Error:", mse)

rmse = root_mean_squared_error(y_true, y_pred)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 34.227500000000006
# Root Mean Squared Error: 5.850427334819227

# %% [markdown]
# ## 1.2 Import
# Importamos todas las librerías necesarias para este análisis: pandas, numpy, seaborn, matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1.3 Carga el dataset de notas de estudiantes
# Para probar a hacer árboles de decisión de Regresión utilizaremos un dataset sobre las notas de ciertos estudiantes portugueses de dos instituos en función de ciertas características socio-demográficas. El dataset original se puede encontrar en Kaggle ([aquí](https://www.kaggle.com/dipam7/student-grade-prediction)).
#
# Podéis encontrar una versión lista para usar con árboles de decisión en  github: [https://raw.githubusercontent.com/abelmmg/TheValley_AI/main/notas_estudiantes_limpio.csv](https://raw.githubusercontent.com/abelmmg/TheValley_AI/main/notas_estudiantes_limpio.csv)
#
# Importa este dataset en un dataframe llamado **df**.

# %%
# URL archivo raw
url = "https://raw.githubusercontent.com/JimenaAreta/thevalley-MDS/refs/heads/jimena/datasets/notas_estudiantes_limpio.csv"
# Importa csv
df = pd.read_csv(url)
df.head()
# Out:
#    Nota  Genero  Edad  Entorno Urbano  Familia <=3  Padres Separados  \
# 0   3.0       0    18               1            0                 1
# 1   3.0       0    17               1            0                 0
# 2   5.0       0    15               1            1                 0
# 3   7.5       0    15               1            0                 0
# 4   5.0       0    16               1            0                 0
#
#    Nivel Edu Madre  Nivel Edu Padre  Tutor No Paterno  Tiempo Casa-Escuela  \
# 0                4                4                 0                    2
# 1                1                1                 0                    1
# 2                1                1                 0                    1
# 3                4                2                 0                    1
# 4                3                3                 0                    1
#
#    ...  Extraescolares  Acceso Internet  Relación Romántica  \
# 0  ...               0                0                   0
# 1  ...               0                1                   0
# 2  ...               0                1                   0
# 3  ...               1                1                   1
# 4  ...               0                0                   0
#
#    Calidad Relación Familiar  Tiempo Estudio  Sale con Amigos  Alcohol Semana  \
# 0                          4               3                4               1
# 1                          5               3                3               1
# 2                          4               3                2               2
# 3                          3               2                2               1
# 4                          4               3                2               1
#
#    Alcohol Finde  Estado Salud  Ausencias
# 0              1             3          6
# 1              1             3          4
# 2              3             3         10
# 3              1             5          2
# 4              2             5          4
#
# [5 rows x 21 columns]

# %% [markdown]
# #2. EDA
# Realizaremos un pequeño analisis exploratorio para familiarizarnos con el dataset.

# %%
# Echamos un vistazo a las 12 columnas.
df.columns
# Out:
# Index(['Nota', 'Genero', 'Edad', 'Entorno Urbano', 'Familia <=3',
#        'Padres Separados', 'Nivel Edu Madre', 'Nivel Edu Padre',
#        'Tutor No Paterno', 'Tiempo Casa-Escuela', 'Tiempo Estudio Semanal',
#        'Extraescolares', 'Acceso Internet', 'Relación Romántica',
#        'Calidad Relación Familiar', 'Tiempo Estudio', 'Sale con Amigos',
#        'Alcohol Semana', 'Alcohol Finde', 'Estado Salud', 'Ausencias'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Nota                       395 non-null    float64
#  1   Genero                     395 non-null    int64
#  2   Edad                       395 non-null    int64
#  3   Entorno Urbano             395 non-null    int64
#  4   Familia <=3                395 non-null    int64
#  5   Padres Separados           395 non-null    int64
#  6   Nivel Edu Madre            395 non-null    int64
#  7   Nivel Edu Padre            395 non-null    int64
#  8   Tutor No Paterno           395 non-null    int64
#  9   Tiempo Casa-Escuela        395 non-null    int64
#  10  Tiempo Estudio Semanal     395 non-null    int64
#  11  Extraescolares             395 non-null    int64
#  12  Acceso Internet            395 non-null    int64
#  13  Relación Romántica         395 non-null    int64
#  14  Calidad Relación Familiar  395 non-null    int64
#  15  Tiempo Estudio             395 non-null    int64
#  16  Sale con Amigos            395 non-null    int64
#  17  Alcohol Semana             395 non-null    int64
#  18  Alcohol Finde              395 non-null    int64
#  19  Estado Salud               395 non-null    int64
#  20  Ausencias                  395 non-null    int64
# dtypes: float64(1), int64(20)
# memory usage: 64.9 KB

# %%
df.describe().T
# Out:
#                            count       mean       std   min   25%   50%   75%  \
# Nota                       395.0   5.207595  2.290721   0.0   4.0   5.5   7.0
# Genero                     395.0   0.473418  0.499926   0.0   0.0   0.0   1.0
# Edad                       395.0  16.696203  1.276043  15.0  16.0  17.0  18.0
# Entorno Urbano             395.0   0.777215  0.416643   0.0   1.0   1.0   1.0
# Familia <=3                395.0   0.288608  0.453690   0.0   0.0   0.0   1.0
# Padres Separados           395.0   0.103797  0.305384   0.0   0.0   0.0   0.0
# Nivel Edu Madre            395.0   2.749367  1.094735   0.0   2.0   3.0   4.0
# Nivel Edu Padre            395.0   2.521519  1.088201   0.0   2.0   2.0   3.0
# Tutor No Paterno           395.0   0.081013  0.273201   0.0   0.0   0.0   0.0
# Tiempo Casa-Escuela        395.0   1.448101  0.697505   1.0   1.0   1.0   2.0
# Tiempo Estudio Semanal     395.0   2.035443  0.839240   1.0   1.0   2.0   2.0
# Extraescolares             395.0   0.508861  0.500555   0.0   0.0   1.0   1.0
# Acceso Internet            395.0   0.832911  0.373528   0.0   1.0   1.0   1.0
# Relación Romántica         395.0   0.334177  0.472300   0.0   0.0   0.0   1.0
# Calidad Relación Familiar  395.0   3.944304  0.896659   1.0   4.0   4.0   5.0
# Tiempo Estudio             395.0   3.235443  0.998862   1.0   3.0   3.0   4.0
# Sale con Amigos            395.0   3.108861  1.113278   1.0   2.0   3.0   4.0
# Alcohol Semana             395.0   1.481013  0.890741   1.0   1.0   1.0   2.0
# Alcohol Finde              395.0   2.291139  1.287897   1.0   1.0   2.0   3.0
# Estado Salud               395.0   3.554430  1.390303   1.0   3.0   4.0   5.0
# Ausencias                  395.0   5.708861  8.003096   0.0   0.0   4.0   8.0
#
#                             max
# Nota                       10.0
# Genero                      1.0
# Edad                       22.0
# Entorno Urbano              1.0
# Familia <=3                 1.0
# Padres Separados            1.0
# Nivel Edu Madre             4.0
# Nivel Edu Padre             4.0
# Tutor No Paterno            1.0
# Tiempo Casa-Escuela         4.0
# Tiempo Estudio Semanal      4.0
# Extraescolares              1.0
# Acceso Internet             1.0
# Relación Romántica          1.0
# Calidad Relación Familiar   5.0
# Tiempo Estudio              5.0
# Sale con Amigos             5.0
# Alcohol Semana              5.0
# Alcohol Finde               5.0
# Estado Salud                5.0
# Ausencias                  75.0

# %%
# Como la variacion standard de 'Tutor No Paterno' esta cerca de 0 le echamos un vistazo

df.groupby("Tutor No Paterno").agg(
    Count=('Tutor No Paterno', 'count'),  # Contar el número de valores
    Sum=('Tutor No Paterno', 'sum')       # Sumar los valores
)
# Out:
#                   Count  Sum
# Tutor No Paterno
# 0                   363    0
# 1                    32   32

# %%
# vemos la proporcion
32 / 363
# Out:
# 0.0881542699724518

# %%
# Visualización de los coeficientes pearson
plt.figure(figsize=(12, 10))

# Calcular la matriz de correlación
correlation_matrix = df.corr()

sns.heatmap(np.round(correlation_matrix, 2), vmin=-1, vmax=1, annot=True, cmap="coolwarm")
plt.show()

# %%
# seleccion de columnas para acortar el tiempo de computo.
col = ['Nota', 'Genero', 'Edad', 'Padres Separados', 'Nivel Edu Madre', 'Nivel Edu Padre',
       'Tiempo Casa-Escuela', 'Tiempo Estudio Semanal',
       'Tiempo Estudio', 'Ausencias']

# %% [markdown]
# # 3. Construcción árbol de decisión scikit learn
# Utilizando la librería [scikit learn](https://scikit-learn.org/stable/), la libería básica de referencia para machine learning, construíremos un árbol de decisión de regresión.

# %%
# Siguiendo el ejemplo de las diapositivas, entrenaremos un modelo
# utilizando sólo las variables 'Nivel Edu Madre', 'Tiempo Estudio', 'Ausencias'
cols = ["Nivel Edu Madre", "Tiempo Estudio", "Ausencias", ]
X = df[cols]
y = df["Nota"]

X.shape, y.shape
# Out:
# ((395, 3), (395,))

# %%
# Características
X
# Out:
#      Nivel Edu Madre  Tiempo Estudio  Ausencias
# 0                  4               3          6
# 1                  1               3          4
# 2                  1               3         10
# 3                  4               2          2
# 4                  3               3          4
# ..               ...             ...        ...
# 390                2               5         11
# 391                3               4          3
# 392                1               5          3
# 393                3               4          0
# 394                1               2          5
#
# [395 rows x 3 columns]

# %%
# Clases
y
# Out:
# 0      3.0
# 1      3.0
# 2      5.0
# 3      7.5
# 4      5.0
#       ...
# 390    4.5
# 391    8.0
# 392    3.5
# 393    5.0
# 394    4.5
# Name: Nota, Length: 395, dtype: float64

# %% [markdown]
# ##3.1 Importamos librerias

# %%
from sklearn import tree

# %% [markdown]
# ## 3.2 Inicializamos el árbol
# Definiendo las características que tendrá.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html

# %%
# Inicialización del árbol
# Solo se define su estructura y condiciones de entrenamiento
arbol = tree.DecisionTreeRegressor(max_depth=3)
arbol
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# # 3.3 Entrenamiento del modelo
# Una vez inicializado y definido el árbol, el método .[fit()](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier.fit)

# %%
# Entrenamiento
arbol.fit(X=X, y=y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %% [markdown]
# # 3.4 Visualización del modelo

# %%
print(tree.export_text(arbol, feature_names=list(X.columns)))
# Out:
# |--- Ausencias <= 0.50
# |   |--- Nivel Edu Madre <= 2.50
# |   |   |--- Nivel Edu Madre <= 0.50
# |   |   |   |--- value: [7.50]
# |   |   |--- Nivel Edu Madre >  0.50
# |   |   |   |--- value: [3.01]
# |   |--- Nivel Edu Madre >  2.50
# |   |   |--- Tiempo Estudio <= 3.50
# |   |   |   |--- value: [4.57]
# |   |   |--- Tiempo Estudio >  3.50
# |   |   |   |--- value: [5.66]
# |--- Ausencias >  0.50
# |   |--- Ausencias <= 13.50
# |   |   |--- Nivel Edu Madre <= 3.50
# |   |   |   |--- value: [5.52]
# |   |   |--- Nivel Edu Madre >  3.50
# |   |   |   |--- value: [6.26]
# |   |--- Ausencias >  13.50
# |   |   |--- Tiempo Estudio <= 2.50
# |   |   |   |--- value: [5.77]
# |   |   |--- Tiempo Estudio >  2.50
# |   |   |   |--- value: [4.47]

# %%
import graphviz

# Export_graphviz
dot_data = tree.export_graphviz(arbol, out_file=None, feature_names=list(X.columns))
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# ## 3.5 Realizamos una predicción
# Una vez el modelo está entrenado (definido) podemos pasarle datos para obtener las prediciones correspondientes de la variable objetivo.
#
# Para esto utilizamos el método .[predict()](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier.predict).

# %%
prediccion = arbol.predict(X)

# %%
np.mean(y)
# Out:
# np.float64(5.207594936708861)

# %%
# ¿como es de buena la prediccion?
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y, prediccion)
print(f'Error Cuadrático Medio (MSE): {mse:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 4.27

# %%
root_mean_squared_error(y, prediccion)
# Out:
# 2.0656132257805306

# %% [markdown]
# **¿Deberíamos evaluar los modelos así?**

# %% [markdown]
# ## 3.6 Volvemos a entrenar pero partiendo el dataset en train y test

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

X_train, X_test, y_train, y_test = train_test_split(df[cols], df["Nota"], test_size=0.1, random_state=42)

# Crear y entrenar el modelo de árbol de decisión
arbol = DecisionTreeRegressor(max_depth=20, random_state=42)
arbol.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = arbol.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (MSE): {mse:.2f}')

rmse = root_mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (RMSE): {rmse:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 5.47
# Error Cuadrático Medio (RMSE): 2.34

# %%
# vamos a ver que esta pasando fila a fila
def mostrar_predicciones(X_test, y_test, y_pred):

    # Asegurarse de que X_test sea un DataFrame para poder acceder a los índices y nombres de columnas
    if isinstance(X_test, pd.DataFrame):
        # Convertir X_test a un DataFrame si no lo es
        X_test = pd.DataFrame(X_test, columns=X_test.columns)
    else:
        X_test = pd.DataFrame(X_test)

    # Asegurarse de que y_test y y_pred sean Series para alinearlos correctamente
    y_test = pd.Series(y_test, name='Real')
    y_pred = pd.Series(y_pred, name='Prediccion', index=y_test.index)

    # Calcular la diferencia absoluta entre los valores predichos y los valores reales
    y_diff = (y_test - y_pred).abs()
    y_diff = pd.Series(y_diff, name='Diff', index=y_test.index)

    # Definir un umbral para considerar un acierto
    umbral = 1.5  # Este valor puede ajustarse según el contexto

    # Calcular el total de aciertos
    aciertos = (y_diff <= umbral).sum()
    print(f'Total de aciertos: {aciertos}')

    fallos = (y_diff > umbral).sum()
    print(f'Total de fallos: {fallos}')

    ratio_aciertos = aciertos / (aciertos + fallos)
    print(f'Ratio aciertos: {ratio_aciertos}')

    # Concatenar X_test, y_test y y_pred para mostrarlos juntos
    # drop=True: se elimina el índice antiguo en lugar de añadirlo como una columna adicional en el DataFrame
    resultados = pd.concat([X_test.reset_index(drop=True), y_test.reset_index(drop=True), y_pred.reset_index(drop=True),  y_diff.reset_index(drop=True)], axis=1)
    print(resultados)

# Usar la función con los datos actuales
mostrar_predicciones(X_test, y_test, y_pred)
# Out:
# Total de aciertos: 22
# Total de fallos: 18
# Ratio aciertos: 0.55
#     Nivel Edu Madre  Tiempo Estudio  Ausencias  Real  Prediccion      Diff
# 0                 2               5          2   5.0    4.000000  1.000000
# 1                 1               3          3   6.0    4.333333  1.666667
# 2                 3               3          8   2.5    5.000000  2.500000
# 3                 2               3          8   5.0    5.500000  0.500000
# 4                 2               5         11   4.5    7.500000  3.000000
# 5                 2               3          0   6.5    2.550000  3.950000
# 6                 4               3          2   9.0    6.571429  2.428571
# 7                 1               4         18   3.0    5.000000  2.000000
# 8                 2               3          0   0.0    2.550000  2.550000
# 9                 4               4          2   7.0    6.214286  0.785714
# 10                3               5          0   7.5    5.250000  2.250000
# 11                4               4          6   3.5    4.750000  1.250000
# 12                3               4          1   7.5    6.000000  1.500000
# 13                3               4          0   5.0    4.500000  0.500000
# 14                2               2          8   7.0    5.500000  1.500000
# 15                2               4          2   4.0    5.250000  1.250000
# 16                2               4          0   4.0    3.500000  0.500000
# 17                1               4          2   5.5    5.500000  0.000000
# 18                0               3          0   7.5    7.500000  0.000000
# 19                2               4          0   0.0    3.500000  3.500000
# 20                4               4          4   7.0    6.250000  0.750000
# 21                3               4          3   8.0    8.000000  0.000000
# 22                4               2          0   8.0    6.250000  1.750000
# 23                4               3          6   3.0    6.166667  3.166667
# 24                4               2          0   0.0    6.250000  6.250000
# 25                4               5         10   9.5    4.333333  5.166667
# 26                2               2          0   5.5    6.250000  0.750000
# 27                3               3          0   6.0    3.150000  2.850000
# 28                4               4          0   8.5    5.950000  2.550000
# 29                4               4          8   5.0    6.000000  1.000000
# 30                4               3         38   4.0    9.000000  5.000000
# 31                1               3          2   5.0    5.187500  0.187500
# 32                4               2          0   7.5    6.250000  1.250000
# 33                4               3          4   6.5    6.750000  0.250000
# 34                3               3          0   4.0    3.150000  0.850000
# 35                4               4         14   2.5    4.000000  1.500000
# 36                3               3          0   0.0    3.150000  3.150000
# 37                4               2          4   7.5    7.600000  0.100000
# 38                3               3          2   7.0    7.250000  0.250000
# 39                2               2         14   4.0    6.500000  2.500000

# %% [markdown]
# # EJERCICIO con todas las características
# Entrena un árbol de regresión con todas las variables predictoras disponibles para predecir la variable 'Nota'.
#
# Prueba con profundidades de 3, 5, 20 y compara la calidad de cada predicción con la del árbol de las celdas anteriores.
#
# Visualiza los distintos árboles y reflexiona sobre cómo ha conseguido mejorar la capacidad predictiva a medida que aumenta la profundidad de la arquitectura.

# %%
cols = ['Genero', 'Edad', 'Entorno Urbano', 'Familia <=3',
       'Padres Separados', 'Nivel Edu Madre', 'Nivel Edu Padre',
       'Tutor No Paterno', 'Tiempo Casa-Escuela', 'Tiempo Estudio Semanal',
       'Extraescolares', 'Acceso Internet', 'Relación Romántica',
       'Calidad Relación Familiar', 'Tiempo Estudio', 'Sale con Amigos',
       'Alcohol Semana', 'Alcohol Finde', 'Estado Salud', 'Ausencias']
X = df[cols]
y = df["Nota"]

# %%
#PROFUNDIDAD DE 3
X_train, X_test, y_train, y_test = train_test_split(df[cols], df["Nota"], test_size=0.1, random_state=42)

# Crear y entrenar el modelo de árbol de decisión
arbol_3_max = DecisionTreeRegressor(max_depth=3, random_state=42)
arbol_3_max.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = arbol_3_max.predict(X_test)

# Evaluar el modelo
mse_3 = mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (MSE): {mse_3:.2f}')

rmse_3 = root_mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (RMSE): {rmse_3:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 6.24
# Error Cuadrático Medio (RMSE): 2.50

# %%
import graphviz

# Export_graphviz
dot_data = tree.export_graphviz(arbol, out_file=None, feature_names=list(X.columns))
graph = graphviz.Source(dot_data)
graph

# %%
#PROFUNIDAD DE 5
# Crear y entrenar el modelo de árbol de decisión
arbol_5_max = DecisionTreeRegressor(max_depth=5, random_state=42)
arbol_5_max.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = arbol_5_max.predict(X_test)

# Evaluar el modelo
mse_5 = mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (MSE): {mse_5:.2f}')

rmse_5 = root_mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (RMSE): {rmse_5:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 6.47
# Error Cuadrático Medio (RMSE): 2.54

# %%
#PROFUNDIDAD DE 20
# Crear y entrenar el modelo de árbol de decisión
arbol_20_max = DecisionTreeRegressor(max_depth=20, random_state=42)
arbol_20_max.fit(X_train, y_train)

# Predecir en el conjunto de prueba
y_pred = arbol_20_max.predict(X_test)

# Evaluar el modelo
mse_20 = mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (MSE): {mse_20:.2f}')

rmse_20 = root_mean_squared_error(y_test, y_pred)
print(f'Error Cuadrático Medio (RMSE): {rmse_20:.2f}')
# Out:
# Error Cuadrático Medio (MSE): 12.61
# Error Cuadrático Medio (RMSE): 3.55
